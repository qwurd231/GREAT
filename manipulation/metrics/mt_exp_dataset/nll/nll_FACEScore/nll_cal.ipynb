# %%
from test import test_pythia_nll
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from test import test_pythia_nll
#
# ImportError: cannot import name 'test_pythia_nll' from 'test' (/home/lxq/anaconda3/envs/py310/lib/python3.10/test/__init__.py)
